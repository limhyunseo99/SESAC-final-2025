# %% [markdown]
# pip install langchain-openai langchain-core langchain-community
# pip install tavily-python
# pip install PyPDF2
# pip install markdown
# pip install weasyprint
# pip install python-dotenv
# pip install fitz PyMuPDF
# pip install reportlab

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.colors import HexColor
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from datetime import datetime

# 폰트 등록
pdfmetrics.registerFont(TTFont("Free-Regular", r"c:\USERS\KMOON\APPDATA\LOCAL\MICROSOFT\WINDOWS\FONTS\FREESENTATION-4REGULAR.TTF"))
pdfmetrics.registerFont(TTFont("Free-Bold", r"c:\USERS\KMOON\APPDATA\LOCAL\MICROSOFT\WINDOWS\FONTS\FREESENTATION-7BOLD.TTF"))


def create_cover_page(path: str, country: str, item: str):
    """PDF 표지 생성"""

    w, h = A4
    today = datetime.now().strftime("%Y-%m-%d")

    c = canvas.Canvas(path, pagesize=A4)

    # 배경 설정
    c.setFillColor(HexColor("#FFFFFF"))
    c.rect(0, 0, w, h, fill=1, stroke=0)

    # 큰 원
    big_r = 540
    big_cx = w + 360
    big_cy = h * 0.55
    c.setFillColor(HexColor("#7DA0CA"))
    c.circle(big_cx, big_cy, big_r, fill=1, stroke=0)

    # 작은 원
    small_r = 320
    small_cx = w * 0.70
    small_cy = -40
    c.setFillColor(HexColor("#052659"))
    c.circle(small_cx, small_cy, small_r, fill=1, stroke=0)

    # 제목
    c.setFillColor(HexColor("#052659"))
    c.setFont("Free-Bold", 40)
    c.drawString(70, h - 200, f"{country} 시장 진출 전략 보고서")

    c.setFont("Free-Bold", 48)
    c.drawString(70, h - 250, "2025")

    c.setFont("Free-Regular", 17)
    c.drawString(70, h - 290, "데이터 기반 해외시장 분석")

    # 구분선
    c.setStrokeColor(HexColor("#021024"))
    c.setLineWidth(1)
    c.line(70, h - 305, 320, h - 305)

    # 설명문
    desc = (
        "본 보고서는 국가정보·진출전략·수출데이터 기반으로 생성되었습니다.\n"
        "AI 기반 분석을 통해 시장성 평가 및 진출 전략을 제공합니다."
    )
    c.setFont("Free-Regular", 13)
    y = h - 330
    for line in desc.split("\n"):
        c.drawString(70, y, line)
        y -= 14

    # 하단 발행정보
    c.setFillColor(HexColor("#FFFFFF"))
    c.setFont("Free-Regular", 10)

    base_y = 40

    c.drawRightString(w - 40, base_y + 20, f"발행일: {today}")
    c.drawRightString(w - 40, base_y + 10, "작성기관: Global Path AI – Market Intelligence Unit")
    c.drawRightString(w - 40, base_y, "저작권: © Global Path AI. All Rights Reserved.")

    c.save()

# %% [markdown]
# - 내부 평가: 거짓 있는지 없는지(1/0), 출처 확인(1/0), llm
# - 서비스 평가: gpt, 제미나이

# %%
import requests

url = 'http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList'
params ={'serviceKey' : 'b53c8fe2b45309b830c37fbcbfc8e7d6387db486ead1ef9ba02827537ff35867', 'strtYymm' : '201601', 'endYymm' : '201601', 'hsSgn' : '', 'cntyCd' : 'US' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>\xec\xa0\x95\xec\x83\x81\xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4.</resultMsg></header><body><items><item><balPayments>1712643409</balPayments><expDlr>5040734289</expDlr><expWgt>1242129883</expWgt><hsCd>-</hsCd><impDlr>3328090880</impDlr><impWgt>1510023156</impWgt><statCd>-</statCd><statCdCntnKor1>-</statCdCntnKor1><statKor>-</statKor><year>\xec\xb4\x9d\xea\xb3\x84</year></item><item><balPayments>-579245</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0101211000</hsCd><impDlr>579245</impDlr><impWgt>5000</impWgt><statCd>US</statCd><statCdCntnKor1>\xeb\xaf\xb8\xea\xb5\xad</statCdCntnKor1><statKor>\xeb\x86\x8d\xea\xb0\x80 \xec\x82\xac\xec\x9c\xa1\xec\x9a\xa9</statKor><year>2016.01</year></item><item><balPayments>-519540</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0101219000</hsCd><impDlr>519540</impDlr><impWgt>3050</impWgt><statCd>US</statCd><statCdCntnKor1>\xeb\
# ...
