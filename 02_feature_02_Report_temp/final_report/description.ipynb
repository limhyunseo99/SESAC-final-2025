# %% [markdown]
# project/
# │
# ├── hts_code/
# ├── streamlit/
# ├──├── app.py           # UI (Streamlit)
# ├──├── pipeline.py      # 핵심 로직 (Research 전체 통합)
# ├──├── config.py        # 설정 + 유틸리티
# ├──├── vectorstore.py   # Qdrant 벡터DB
# ├──├── generator.py     # 보고서/PDF 생성
# ├──├── logger.py        # 로그 기록 생성
# ├──└── logs/            # 로그 기록 저장
# │
# ├── data/            # 데이터 폴더
# ├── output/          # 결과물
# └── .env             # 환경변수
