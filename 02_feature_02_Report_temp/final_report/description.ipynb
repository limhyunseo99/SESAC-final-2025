# %% [markdown]
# project/
# │
# ├── hts_code/
# ├── streamlit/
# ├──├── app.py           # UI (Streamlit)
# ├──├── pipeline.py      # 핵심 로직 (Research 전체 통합)
# ├──├── config.py        # 설정 + 유틸리티
# ├──├── vectorstore.py   # Qdrant 벡터DB
# ├──├── generator.py     # 보고서/PDF 생성
# ├──├── logger.py        # 로그 기록 생성
# ├──└── logs/            # 로그 기록 저장
# │
# ├── data/            # 데이터 폴더
# ├── output/          # 결과물
# └── .env             # 환경변수

# %%
import pandas as pd
from config import DATA_DIR

df = pd.read_csv(DATA_DIR / "sns.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import os
#       4 # 현재 파일 기준 상대경로 설정
# ----> 5 DATA_DIR = os.path.join(os.path.dirname(__file__), "..", "data")
#       7 csv_path = os.path.join(DATA_DIR, "sns.csv")
#       9 df_csv = pd.read_csv(csv_path, encoding="utf-8")
#
# NameError: name '__file__' is not defined

# %%
import pandas as pd
import os

DATA_DIR = os.path.join(os.path.dirname(__file__), "..", "data")

xlsx_path = os.path.join(DATA_DIR, "sns.xlsx")

df_xlsx = pd.read_excel(xlsx_path)
print(df_xlsx.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 import os
# ----> 4 DATA_DIR = os.path.join(os.path.dirname(__file__), "..", "data")
#       6 xlsx_path = os.path.join(DATA_DIR, "sns.xlsx")
#       8 df_xlsx = pd.read_excel(xlsx_path)
#
# NameError: name '__file__' is not defined
